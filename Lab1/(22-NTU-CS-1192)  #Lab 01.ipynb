# %% [markdown]
# ## TASK 1

# %%
import pandas as pd

data={'Name':['Anil','Bimal','Chetan','Dinesh','Eshan'],
     'Age':[23,24,22,25,26],
     'City':['Delhi','Mumbai','Chennai','Kolkata','Pune'],
     'salary':[50000,60000,55000,65000,70000]}

df=pd.DataFrame(data)
print("Manunal DataFrame\n")
print(df)
# Out:
# Manunal DataFrame
#
#      Name  Age     City  salary
# 0    Anil   23    Delhi   50000
# 1   Bimal   24   Mumbai   60000
# 2  Chetan   22  Chennai   55000
# 3  Dinesh   25  Kolkata   65000
# 4   Eshan   26     Pune   70000

# %% [markdown]
# ## Task 2

# %%
import pandas as pd
df_csv=pd.read_csv('diabetes.csv')
print("\nDataFrame from CSV file\n")
print(df_csv.head())   
import pandas as pd
online_csv_url='https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
df_online=pd.read_csv(online_csv_url)
print("\nDataFrame from online CSV file\n")
print(df_online.head())
# Out:
# DataFrame from CSV file
#
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# DataFrame from online CSV file
#
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# ...

# %% [markdown]
# ## Task 3

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
data={
    'ID':range(1,101),
    'Score':np.random.randint(20,49,100),
    'Height':np.random.normal(150,190,100).round(1),
    'Weight':np.random.normal(30,3,100).round(1)    
}
df_numpy = pd.DataFrame(data)
print("\nDataFrame from NumPy arrays\n")
print(df_numpy.head())  # Displaying only the first 5 rows for brevity
# Out:
# DataFrame from NumPy arrays
#
#    ID  Score  Height  Weight
# 0   1     26   128.0    25.2
# 1   2     39    92.8    30.6
# 2   3     48  -130.9    30.8
# 3   4     34    13.2    32.3
# 4   5     30    62.5    26.3

# %% [markdown]
# # Task 4

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
data={
    'A':[1,2,None,4,5],
    'B':[6,None,8,9,10],
    'C':[11,12,13,None,15],
}
df3=pd.DataFrame(data)
print("Original DataFrame)\n")
print(df3)
# Out:
# Original DataFrame)
#
#      A     B     C
# 0  1.0   6.0  11.0
# 1  2.0   NaN  12.0
# 2  NaN   8.0  13.0
# 3  4.0   9.0   NaN
# 4  5.0  10.0  15.0

# %% [markdown]
# ## Task 5

# %%
dropna_rows=df3.dropna(axis=0)
print("\nDataFrame after dropping rows with NaN values\n",dropna_rows)

dropna_col=df3.dropna(axis=1)
print("\nDataFrame after dropping columns with NaN values\n",dropna_col)


filna_median=df3.fillna(df3.median())
print("\nDataFrame after filling NaN values with median\n",filna_median)
# Out:
# DataFrame after dropping rows with NaN values
#       A     B     C
# 0  1.0   6.0  11.0
# 4  5.0  10.0  15.0
#
# DataFrame after dropping columns with NaN values
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
#
# DataFrame after filling NaN values with median
#       A     B     C
# 0  1.0   6.0  11.0
# 1  2.0   8.5  12.0
# 2  3.0   8.0  13.0
# 3  4.0   9.0  12.5
# 4  5.0  10.0  15.0

# %% [markdown]
# # TASK 6

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

features_df=pd.DataFrame({'Regionname':['East','West','North','South','East']})

le=LabelEncoder()

features_df['Region']=le.fit_transform(features_df['Regionname'])


print("\nLabel Encoded Region \n")
print(features_df.value_counts())
# Out:
# Label Encoded Region
#
# Regionname  Region
# East        0         2
# North       1         1
# South       2         1
# West        3         1
# Name: count, dtype: int64

# %% [markdown]
# # TASK 7

# %%
features=pd.DataFrame({
            'method':['method1','method2','method1','method3','method2']})
df_one_hot=pd.get_dummies(features,columns=['method'])

print("\nOne-Hot Encoded DataFrame\n")
print(df_one_hot.value_counts())
# Out:
# One-Hot Encoded DataFrame
#
# method_method1  method_method2  method_method3
# False           True            False             2
# True            False           False             2
# False           False           True              1
# Name: count, dtype: int64

# %% [markdown]
# # TASK 8

# %%
import matplotlib.pyplot as plt

data=[10,12,11,13,12,14,70,13,100]

plt.boxplot(data)
plt.title("Show outliers")
plt.show()

# %% [markdown]
# ## # ACTIVITY 1-5

# %%
# ACTIVITY 1

import pandas as pd
data = {
    "Province": ["Punjab", "Sindh", "Khyber Pakhtunkhwa", "Balochistan"],
    "Population (millions)": [110, 47, 35, None],  
    "Literacy Rate (%)": [64, 58, None, 46],       
    "Region": ["East", "South", "North", "West"]
}


df=pd.DataFrame(data)
df
# Out:
#              Province  Population (millions)  Literacy Rate (%) Region
# 0              Punjab                  110.0               64.0   East
# 1               Sindh                   47.0               58.0  South
# 2  Khyber Pakhtunkhwa                   35.0                NaN  North
# 3         Balochistan                    NaN               46.0   West

# %%
df.isnull().sum()

df=df.dropna(subset=['Population (millions)'])

median_lit=df['Literacy Rate (%)'].median()
df.loc[:,'Literacy Rate (%)']=df['Literacy Rate (%)'].fillna(median_lit)

# %%
# Out:
#              Province  Population (millions)  Literacy Rate (%) Region
# 0              Punjab                  110.0               64.0   East
# 1               Sindh                   47.0               58.0  South
# 2  Khyber Pakhtunkhwa                   35.0               61.0  North

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df.loc[:,'Region_Label']=le.fit_transform(df['Region'])
# Out:
# C:\Users\Chishty Computer\AppData\Local\Temp\ipykernel_5936\2954626391.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Region_Label']=le.fit_transform(df['Region'])

# %%
df
# Out:
#              Province  Population (millions)  Literacy Rate (%) Region  \
# 0              Punjab                  110.0               64.0   East
# 1               Sindh                   47.0               58.0  South
# 2  Khyber Pakhtunkhwa                   35.0               61.0  North
#
#    Region_Label
# 0             0
# 1             2
# 2             1

# %%
df=pd.get_dummies(df,columns=['Region']).copy()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(df['Population (millions)'],df['Literacy Rate (%)'],c='blue',s=100)

for i in range(len(df)):
    x = df["Population (millions)"].iloc[i]
    y = df["Literacy Rate (%)"].iloc[i]
    name = df["Province"].iloc[i]
    plt.text(x + 1, y, name, fontsize=10)  

plt.title("Population VS Literacy Rate")
plt.xlabel("Population (millions)")
plt.ylabel("Literacy Rate (%)")
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df["Literacy Rate (%)"], vert=True, patch_artist=True)

# Add province names as scatter points
for i, row in df.iterrows():
    plt.scatter(1, row["Literacy Rate (%)"], label=row["Province"])

plt.title("Boxplot of Literacy Rate (%)")
plt.ylabel("Literacy Rate (%)")
plt.legend()
plt.show()

# %% [markdown]
# # Activity 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Random seed for reproducibility
np.random.seed(42)

# Generate random dataset for 100 students
data = {
    "ID": range(1, 101),
    "Math": np.random.randint(30, 100, 100).astype(float),
    "Science": np.random.randint(35, 95, 100).astype(float),
    "English": np.random.randint(25, 90, 100).astype(float),
    "Grade": np.random.choice(["A", "B", "C"], 100, p=[0.3, 0.5, 0.2])
}
df = pd.DataFrame(data)

# Introduce some missing values randomly
for col in ["Math", "Science", "English"]:
    df.loc[np.random.choice(df.index, 5, replace=False), col] = np.nan

# Handle missing values: fill with mean
df.fillna(df.mean(numeric_only=True), inplace=True)

# Encode categorical Grade column
le = LabelEncoder()
df["Grade_encoded"] = le.fit_transform(df["Grade"])

# Plot histogram of Math scores
plt.figure(figsize=(7,5))
plt.hist(df["Math"], bins=10, color="skyblue", edgecolor="black")
plt.title("Histogram of Math Scores")
plt.xlabel("Math Score")
plt.ylabel("Frequency")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Add total score column
df["Total"] = df[["Math", "Science", "English"]].sum(axis=1)

# Boxplot to detect outliers in total score
plt.figure(figsize=(7,5))
plt.boxplot(df["Total"], vert=True, patch_artist=True)
plt.title("Boxplot of Total Scores")
plt.ylabel("Total Score")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Outlier detection using IQR method
Q1 = df["Total"].quantile(0.25)
Q3 = df["Total"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["Total"] < lower_bound) | (df["Total"] > upper_bound)]

print("Outlier Students in Total Score:\n", outliers[["ID", "Total", "Grade"]])

# Summary: average total score by grade
summary = df.groupby("Grade")["Total"].mean().sort_values(ascending=False)
print("\nAverage Total Score by Grade:\n", summary)
# Out:
# Outlier Students in Total Score:
#  Empty DataFrame
# Columns: [ID, Total, Grade]
# Index: []
#
# Average Total Score by Grade:
#  Grade
# C    188.416374
# A    186.080972
# B    183.813464
# Name: Total, dtype: float64

# %% [markdown]
# # Activity 3

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasets/covid-19/master/data/time-series-19-covid-combined.csv"
df = pd.read_csv(url)
df.head()
# Out:
#          Date Country/Region Province/State  Confirmed  Recovered  Deaths
# 0  2020-01-22    Afghanistan            NaN          0        0.0       0
# 1  2020-01-23    Afghanistan            NaN          0        0.0       0
# 2  2020-01-24    Afghanistan            NaN          0        0.0       0
# 3  2020-01-25    Afghanistan            NaN          0        0.0       0
# 4  2020-01-26    Afghanistan            NaN          0        0.0       0

# %%
df.isnull().sum()
# Out:
# Date                   0
# Country/Region         0
# Province/State    159120
# Confirmed              0
# Recovered          13056
# Deaths                 0
# dtype: int64

# %%
Pakistan_data=df[df["Country/Region"]=="Pakistan"].copy()
Pakistan_data
# Out:
#               Date Country/Region  Confirmed  Recovered  Deaths
# 168912  2020-01-22       Pakistan          0        0.0       0
# 168913  2020-01-23       Pakistan          0        0.0       0
# 168914  2020-01-24       Pakistan          0        0.0       0
# 168915  2020-01-25       Pakistan          0        0.0       0
# 168916  2020-01-26       Pakistan          0        0.0       0
# ...            ...            ...        ...        ...     ...
# 169723  2022-04-12       Pakistan    1526829        0.0   30362
# 169724  2022-04-13       Pakistan    1526952        0.0   30362
# 169725  2022-04-14       Pakistan    1526952        0.0   30362
# 169726  2022-04-15       Pakistan    1527151        0.0   30363
# 169727  2022-04-16       Pakistan    1527248        0.0   30363
#
# [816 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date              0
# Country/Region    0
# Confirmed         0
# Recovered         0
# Deaths            0
# dtype: int64

# %%
# Cell 5: Plot line chart of confirmed cases over time
plt.figure(figsize=(10,6))
plt.plot(Pakistan_data["Date"], Pakistan_data["Confirmed"], marker='o', color="blue", label="Confirmed Cases")
plt.xticks(rotation=45)
plt.xlabel("Date")
plt.ylabel("Confirmed Cases")
plt.title("COVID-19 Confirmed Cases in Pakistan Over Time")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
max_confirmed = Pakistan_data["Confirmed"].max()

max_day_query = Pakistan_data.query("Confirmed == @max_confirmed")[["Date", "Confirmed"]]
print("Day with Highest Confirmed Cases :\n", max_day_query)
# Out:
# Day with Highest Confirmed Cases :
#                Date  Confirmed
# 169727  2022-04-16    1527248

# %%
# Cell 7: Calculate daily new cases
Pakistan_data["Daily_Cases"] = Pakistan_data["Confirmed"].diff().fillna(0)
Pakistan_data.head()
# Out:
#               Date Country/Region  Confirmed  Recovered  Deaths  Daily_Cases
# 168912  2020-01-22       Pakistan          0        0.0       0          0.0
# 168913  2020-01-23       Pakistan          0        0.0       0          0.0
# 168914  2020-01-24       Pakistan          0        0.0       0          0.0
# 168915  2020-01-25       Pakistan          0        0.0       0          0.0
# 168916  2020-01-26       Pakistan          0        0.0       0          0.0

# %%
import seaborn as sns

plt.figure(figsize=(7,5))
sns.boxplot(y=Pakistan_data["Daily_Cases"], color="orange")
plt.title("Boxplot of Daily COVID-19 Cases in Pakistan")
plt.ylabel("Daily Cases")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# # Activity 4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
students = pd.read_csv("students.csv")          
attendance = pd.read_json("attendance.json")    
extra = pd.read_excel("extra.xlsx")

# %%
df = students.merge(attendance, on="Name").merge(extra, on="Name")
print(df.head())
# Out:
#         Name  Marks  Attendance  Bonus
# 0  Student_1     78          86      4
# 1  Student_2     91          56      7
# 2  Student_3     68          70      9
# 3  Student_4     54          58      8
# 4  Student_5     82          88      8

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Attendance"], df["Marks"], color="blue", label=">= 70% Attendance")


low_att = df[df["Attendance"] < 70]
plt.scatter(low_att["Attendance"], low_att["Marks"], color="red", label="< 70% Attendance")

plt.xlabel("Attendance (%)")
plt.ylabel("Marks")
plt.title("Marks vs Attendance (with Low Attendance Highlighted)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
df_one_hot = pd.get_dummies(df, columns=["Name"], prefix="Student")
print(df_one_hot.head())
# Out:
#    Marks  Attendance  Bonus  Student_Student_1  Student_Student_10  \
# 0     78          86      4               True               False
# 1     91          56      7              False               False
# 2     68          70      9              False               False
# 3     54          58      8              False               False
# 4     82          88      8              False               False
#
#    Student_Student_11  Student_Student_12  Student_Student_13  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    Student_Student_14  Student_Student_15  ...  Student_Student_46  \
# 0               False               False  ...               False
# ...

# %% [markdown]
# # Activity 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
data = {
    "Name": ["Ahsan", "Hira", "Bilal", "Zara", "Salman", "Mahnoor"],
    "Age": [25, 27, 35, 29, None, 40],
    "Salary": [50000, None, 75000, 2000000, 60000, 90000],
    "Department": ["IT", "Finance", "IT", "HR", "Finance", "IT"]
}
df = pd.DataFrame(data)
print("Original Data:\n", df)
# Out:
# Original Data:
#        Name   Age     Salary Department
# 0    Ahsan  25.0    50000.0         IT
# 1     Hira  27.0        NaN    Finance
# 2    Bilal  35.0    75000.0         IT
# 3     Zara  29.0  2000000.0         HR
# 4   Salman   NaN    60000.0    Finance
# 5  Mahnoor  40.0    90000.0         IT

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)       
df["Salary"].fillna(df["Salary"].mean(), inplace=True)   
print("\nAfter Handling Missing Values:\n", df)
# Out:
# After Handling Missing Values:
#        Name   Age     Salary Department
# 0    Ahsan  25.0    50000.0         IT
# 1     Hira  27.0   455000.0    Finance
# 2    Bilal  35.0    75000.0         IT
# 3     Zara  29.0  2000000.0         HR
# 4   Salman  29.0    60000.0    Finance
# 5  Mahnoor  40.0    90000.0         IT
# C:\Users\Chishty Computer\AppData\Local\Temp\ipykernel_5936\2815608166.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# ...

# %%
le = LabelEncoder()
df["Department_encoded"] = le.fit_transform(df["Department"])
print("\nEncoded Department:\n", df[["Department", "Department_encoded"]])
# Out:
# Encoded Department:
#    Department  Department_encoded
# 0         IT                   2
# 1    Finance                   0
# 2         IT                   2
# 3         HR                   1
# 4    Finance                   0
# 5         IT                   2

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df["Salary"], patch_artist=True)
plt.title("Boxplot of Salaries")
plt.ylabel("Salary")
plt.grid(axis="y",  alpha=0.9)
plt.show()

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["Salary"] < lower_bound) | (df["Salary"] > upper_bound)]
print("\nOutliers Detected:\n", outliers)
# Out:
# Outliers Detected:
#     Name   Age     Salary Department  Department_encoded
# 3  Zara  29.0  2000000.0         HR                   1
